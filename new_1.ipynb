# %%
from flask import Flask, render_template, request, jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
searchstring="iphone11"

# %%
flipcart_url="https://www.flipkart.com/search?q=" + searchstring

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
uclinet=uReq(flipcart_url)

# %%
flipkartpage=uclinet.read()

# %%
flipkartpage
# Out:
# b''

# %%
flipkart_html = bs(flipkartpage ,"html.parser")

# %%
flipkart_html

# %%
print('avijit')
# Out:
# avijit

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "samsung"

# %%
flipkartPage = uReq(flipkart_url).read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.103f43.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="_2SqgSY" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall 
# ...

# %%
 bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
box=bigboxes[0]

# %%
len(bigboxes)
# Out:
# 12

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="_2SqgSY" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall 
# ...

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
del bigboxes[0:3]

# %%
box = bigboxes[0]

# %%
productLink
# Out:
# 'https://www.flipkart.com/samsung-crystal-4k-neo-series-108-cm-43-inch-ultra-hd-4k-led-smart-tizen-tv-black-2022-model/p/itma076c4dd16aa4?pid=TVSGEAGP9GXWCHCX&lid=LSTTVSGEAGP9GXWCHCXSVNDV5&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_9&otracker=search&fm=organic&iid=77c2c0eb-4e2c-4b8e-bf7a-9c73732dc515.TVSGEAGP9GXWCHCX.SEARCH&ppt=None&ppn=None&ssid=1rdhm70ccw0000001679764224761&qH=fe546279a62683de'

# %%
prodRes = requests.get(productLink)

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Classy product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">I bought samsung 55 inch ultra tv on Flipkart. After 15 days awaming performance of tv. I have long analysis before buy it. First picture quality of tv is awesome and crystal clear. Side viewing angle is great. Sound quality is superb. Software and design mind blowing. Superb support for tv installation. Must buy without second thought. Mi and vu frame can't be compared with samsung...</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202204/blobio-imr-202204_6f110e024f6f4e64982202da84573c63.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class=
# ...

# %%
len(commentboxes)
# Out:
# 11

# %%
commentboxes[0].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Classy product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">I bought samsung 55 inch ultra tv on Flipkart. After 15 days awaming performance of tv. I have long analysis before buy it. First picture quality of tv is awesome and crystal clear. Side viewing angle is great. Sound quality is superb. Software and design mind blowing. Superb support for tv installation. Must buy without second thought. Mi and vu frame can't be compared with samsung...</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202204/blobio-imr-202204_6f110e024f6f4e64982202da84573c63.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class
# ...

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'jayakumar T'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    print(commentboxes[i].div.div.div.p.text)
    #print(commentboxes[i].div.div.find_all('div', {'class': ''}))
    comtag = commentboxes[i].div.div.find_all('div', {'class': ''})
    print(comtag[0].div.text)
    print("\n")
# Out:
# jayakumar T
# 5
# Classy product
# I bought samsung 55 inch ultra tv on Flipkart. After 15 days awaming performance of tv. I have long analysis before buy it. First picture quality of tv is awesome and crystal clear. Side viewing angle is great. Sound quality is superb. Software and design mind blowing. Superb support for tv installation. Must buy without second thought. Mi and vu frame can't be compared with samsung...
#
#
# Harshavardhan Bijjarapu
# 5
# Just wow!
# I have ordered tv on 8th May it arrived on 12th May Very fast delivery and the product is very good The display quality is so good sound quality is 10/10Display is 10/10Connectivity is so fast Overall worth buying
#
#
# Sagar Aru
# 5
# Excellent
# ...

# %%
m='https://www.cafecoffeeday.com/'

# %%
f = uReq(m)

# %%
p=f.read()

# %%
p
# Out:
# b'<!DOCTYPE html><html><head><meta charset="utf-8" /><link rel="shortcut icon" href="https://www.cafecoffeeday.com/sites/default/files/64x64-CCD_6_0.png" type="image/png" /><meta name="description" content="Find the best place to hang out with friends. Visit Caf\xc3\xa9 Coffee Day and enjoy hot coffees, cold coffees, snacks and more. CCD is the best place to spend time with companions." /><meta name="keywords" content="coffee shops, ccd, coffee day, coffee shop, cafe restaurant, coffee restaurant" /><meta name="generator" content="Drupal 7 (http://drupal.org)" /><link rel="canonical" href="https://www.cafecoffeeday.com/" /><link rel="shortlink" href="https://www.cafecoffeeday.com/node/769" /><meta property="og:site_name" content="Cafe Coffee Day \xe2\x80\x93 India&#039;s favourite Coffee Shop &amp; hangout place" /><meta property="og:url" content="https://www.cafecoffeeday.com/" /><meta property="og:type" content="article" /><meta property="og:title" content="Caf\xc3\xa9 Coffee Day |
# ...

# %%
fl = bs(p, "html.parser")

# %%
fl
# Out:
# <!DOCTYPE html>
# ...

# %%
len(fl)
# Out:
# 2

# %%
co = fl.find_all('div', {'class': "_16PBlm"})
# Out:
#   Cell In [53], line 1
#     fl[]
#        ^
# SyntaxError: invalid syntax
