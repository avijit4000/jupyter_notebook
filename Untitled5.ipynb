# %%
import pandas as pd
import numpy as np

# %%
xls=pd.ExcelFile('D:\Docments\Excel\Bank Statments\Account_Statement_241022_220423.xls')
df1=pd.read_excel(xls,'Sheet1')

# %%
df1
# Out:
#           Date and Time                                          Narration  \
# 0   03-04-2023 15:41:36  Money Sent using UPI\nSent to: Hemalatha Wife ...
# 1   31-03-2023 07:12:13  Received for Automatic Payment\nReceived for A...
# 2   04-02-2023 19:56:00  Money Sent using UPI\nSent to: MD ASLAM\nVPA: ...
# 3   04-11-2022 09:38:09  Money Sent using UPI\nSent to: L T Mtp Cheftal...
# 4   04-11-2022 13:12:47  Money Sent using UPI\nSent to: Kushi Bhavan\nV...
# ..                  ...                                                ...
# 77  01-02-2023 07:08:38  Received for Automatic Payment\nReceived for A...
# 78  31-03-2023 07:27:57  Money Sent using UPI\nSent to: Revenue Account...
# 79                Total                                                NaN
# 80                  NaN                                                NaN
# 81                  NaN                                                NaN
#
#     Amount Type  Available balance Beneficiary Account number  \
# ...

# %%
df1.head()
# Out:
#          Date and Time                                          Narration  \
# 0  03-04-2023 15:41:36  Money Sent using UPI\nSent to: Hemalatha Wife ...
# 1  31-03-2023 07:12:13  Received for Automatic Payment\nReceived for A...
# 2  04-02-2023 19:56:00  Money Sent using UPI\nSent to: MD ASLAM\nVPA: ...
# 3  04-11-2022 09:38:09  Money Sent using UPI\nSent to: L T Mtp Cheftal...
# 4  04-11-2022 13:12:47  Money Sent using UPI\nSent to: Kushi Bhavan\nV...
#
#    Amount Type  Available balance Beneficiary Account number  \
# 0   200.0    D            1770.52                        NaN
# 1   165.0    C            2268.52                        NaN
# 2    80.0    D            6474.47                        NaN
# 3    20.0    D              65.47                        NaN
# 4    55.0    D              10.47                        NaN
#
#        Beneficiary name Remitter Account number  Remitter name  \
# 0   Hemalatha Wife Of C  7908023338avijit@paytm  AVIJIT BISWAS
# ...

# %%
df1.tail()
# Out:
#           Date and Time                                          Narration  \
# 77  01-02-2023 07:08:38  Received for Automatic Payment\nReceived for A...
# 78  31-03-2023 07:27:57  Money Sent using UPI\nSent to: Revenue Account...
# 79                Total                                                NaN
# 80                  NaN                                                NaN
# 81                  NaN                                                NaN
#
#     Amount Type  Available balance Beneficiary Account number  \
# 77    30.0    C            4053.47                        NaN
# 78   300.0    D            1968.52                        NaN
# 79   280.0  NaN                NaN                        NaN
# 80     NaN  NaN                NaN                        NaN
# 81   280.0  NaN                NaN                        NaN
#
#                Beneficiary name Remitter Account number  Remitter name  \
# ...

# %%
df2=df1[df1['Type']=='D']
df2
# Out:
#           Date and Time                                          Narration  \
# 0   03-04-2023 15:41:36  Money Sent using UPI\nSent to: Hemalatha Wife ...
# 2   04-02-2023 19:56:00  Money Sent using UPI\nSent to: MD ASLAM\nVPA: ...
# 3   04-11-2022 09:38:09  Money Sent using UPI\nSent to: L T Mtp Cheftal...
# 4   04-11-2022 13:12:47  Money Sent using UPI\nSent to: Kushi Bhavan\nV...
# 6   05-02-2023 21:11:41  Money Sent using UPI\nSent to: DHARMARAJU D S ...
# 7   07-03-2023 05:35:58  Paid using your Bank Account\nPaid successfull...
# 10  07-03-2023 19:41:53  Paid using your Bank Account\nPaid successfull...
# 11  07-03-2023 19:46:20  Paid using your Bank Account\nPaid successfull...
# 12  08-02-2023 09:04:01  Money Sent using UPI\nSent to: AVIJIT BISWAS\n...
# 14  08-02-2023 09:05:06  Money Sent using UPI\nSent to: AVIJIT BISWAS\n...
# 17  08-02-2023 13:35:11  Money Sent using UPI\nSent to: Jio Mobility\nV...
# ...

# %%
df2['Available balance'].sum()
# Out:
# 72429.99

# %%
df2['Amount'].sum()
# Out:
# 20160.6
