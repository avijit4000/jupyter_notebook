# %%
import pandas as pd

# %%
purchase_data = pd.read_csv('D:\Pyn\sept\data.tsv.txt',sep ='\t')
purchase_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
purchase_data.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
purchase_data.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
purchase_data.shape
# Out:
# (4622, 5)

# %%
purchase_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
purchase_data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
purchase_data.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
purchase_data['order_id'].nunique()
# Out:
# 1834

# %%
purchase_data['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
purchase_data['item_name'].nunique()
# Out:
# 50

# %%
purchase_data.groupby(by='item_name')['quantity'].sum().sort_values(ascending = False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
user_details = pd.read_csv('u.user',sep = '|')
user_details
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
user_details.shape
# Out:
# (943, 5)

# %%
user_details.isna().sum()
# Out:
# user_id       0
# age           0
# gender        0
# occupation    0
# zip_code      0
# dtype: int64

# %%
user_details.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
user_details.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
user_details['occupation'].unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
user_details['occupation'].nunique()
# Out:
# 21

# %%
user_details['gender'].value_countsts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
user_details['occupation'].value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
    user_details.groupby(by='occupation')['age'].mean().round().sort_values(ascending=False)
# Out:
# occupation
# retired          63.0
# doctor           44.0
# educator         42.0
# healthcare       42.0
# librarian        40.0
# executive        39.0
# administrator    39.0
# marketing        38.0
# lawyer           37.0
# engineer         36.0
# salesman         36.0
# scientist        36.0
# writer           36.0
# other            35.0
# homemaker        33.0
# programmer       33.0
# technician       33.0
# artist           31.0
# entertainment    29.0
# none             27.0
# student          22.0
# Name: age, dtype: float64

# %%
    user_details.groupby(by=['gender','occupation'])['age'].mean().round()
# Out:
# gender  occupation
# F       administrator    41.0
#         artist           30.0
#         educator         39.0
#         engineer         30.0
#         entertainment    31.0
#         executive        44.0
#         healthcare       40.0
#         homemaker        34.0
#         lawyer           40.0
#         librarian        40.0
#         marketing        37.0
#         none             36.0
#         other            35.0
#         programmer       32.0
#         retired          70.0
#         salesman         27.0
#         scientist        28.0
#         student          21.0
#         technician       38.0
#         writer           38.0
# M       administrator    37.0
#         artist           32.0
#         doctor           44.0
#         educator         43.0
#         engineer         37.0
#         entertainment    29.0
#         executive        38.0
#         healthcare       45.0
#         homemaker        23.0
#         lawyer           36.0
# ...

# %%
user_details.groupby(by=['gender','occupation'])['user_id','age'].mean().round()
# Out:
# C:\Users\aviji\AppData\Local\Temp\ipykernel_9608\2889464279.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   user_details.groupby(by=['gender','occupation'])['user_id','age'].mean().round()
#                       user_id   age
# gender occupation
# F      administrator    444.0  41.0
#        artist           432.0  30.0
#        educator         455.0  39.0
#        engineer         806.0  30.0
#        entertainment    780.0  31.0
#        executive        373.0  44.0
#        healthcare       568.0  40.0
#        homemaker        367.0  34.0
#        lawyer           285.0  40.0
#        librarian        449.0  40.0
#        marketing        443.0  37.0
#        none             522.0  36.0
#        other            475.0  35.0
#        programmer       411.0  32.0
#        retired          860.0  70.0
#        salesman         638.0  27.0
#        scientist        612.0  28.0
# ...

# %%
team_performance_stats = pd.read_csv('D:\Pyn\sept\Euro_2012_stats_TEAM.csv')
team_performance_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
pd.set_option('max_columns',None)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In [44], line 1
# ----> 1 pd.set_option('max_columns',None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_config\config.py:264, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     263 def __call__(self, *args, **kwds) -> T:
# --> 264     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_config\config.py:157, in _set_option(*args, **kwargs)
#     154     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     156 for k, v in zip(args[::2], args[1::2]):
# --> 157     key = _get_single_key(k, silent)
#     159     o = _get_registered_option(key)
#     160     if o and o.validator:
#
# ...
