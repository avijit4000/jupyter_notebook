# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
url='https://www.flipkart.com/search?q='+'5g_mobile'

# %%
url
# Out:
# 'https://www.flipkart.com/search?q=5g_mobile'

# %%
uclient=uReq(url)

# %%
uclient

# %%
fuclient=uclient.read()

# %%
uclient.close()

# %%
fuclient
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flhtml=bs(fuclient,"html.parser")

# %%
flhtml
# Out:
# <!DOCTYPE html>
# ...

# %%
cmbox=flhtml.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
cmbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=5g_mobile&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=ty
# ...

# %%
len(cmbox)
# Out:
# 30

# %%
cmbox[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=5g_mobile&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
cmbox[3].div.div.div.text
# Out:
# 'Add to Comparevivo T2x 5G (Aurora Gold, 128 GB)4.63,040 Ratings\xa0&\xa0110 Reviews4 GB RAM | 128 GB ROM16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh BatteryDimensity 6020 Processor1 Year of Device & 6 Months for Inbox Accessories₹12,999₹17,99927% offFree deliveryUpto ₹12,450 Off on ExchangeBank Offer'

# %%
for i in cmbox:
    print(i.div.div.div.text)
# Out:
# Filters
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [26], line 2
#       1 for i in cmbox:
# ----> 2     print(i.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
cmbox[10]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGDRGPQQGTRXU9" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/poco-m4-5g-power-black-128-gb/p/itm967111aabdc3f?pid=MOBGDRGPQQGTRXU9&amp;lid=LSTMOBGDRGPQQGTRXU9P0JJRO&amp;marketplace=FLIPKART&amp;q=5g_mobile&amp;store=tyy%2F4io&amp;srno=s_1_9&amp;otracker=search&amp;fm=organic&amp;iid=9c1a47c9-cfdb-43fb-a941-24f9dea7bff8.MOBGDRGPQQGTRXU9.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=w779evh1lc0000001682776795293&amp;qH=5ea6ea0c886e1490" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="POCO M4 5G (Power Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/l2jcccw0/mobile/i/1/y/-original-imagdu8gtefvchbn.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="c
# ...

# %%
cmbox[20]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGC2Q5HJWMYFA2" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/realme-9-5g-se-azure-glow-128-gb/p/itmc13efe78f2116?pid=MOBGC2Q5HJWMYFA2&amp;lid=LSTMOBGC2Q5HJWMYFA2PQNDCT&amp;marketplace=FLIPKART&amp;q=5g_mobile&amp;store=tyy%2F4io&amp;srno=s_1_19&amp;otracker=search&amp;fm=organic&amp;iid=9c1a47c9-cfdb-43fb-a941-24f9dea7bff8.MOBGC2Q5HJWMYFA2.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=w779evh1lc0000001682776795293&amp;qH=5ea6ea0c886e1490" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="realme 9 5G SE (Azure Glow, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/l0jwbrk0/mobile/b/w/1/-original-imagcb668sagq8wf.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" 
# ...

# %%
cmbox[10].div.div.text
# Out:
# 'Add to ComparePOCO M4 5G (Power Black, 128 GB)4.234,907 Ratings\xa0&\xa02,579 Reviews6 GB RAM | 128 GB ROM | Expandable Upto 512 GB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion Polymer BatteryMediatek Dimensity 700 Processor1 Year Warranty for Handset and 6 Months for Accessories₹14,999₹18,99921% offFree deliveryUpto ₹14,450 Off on ExchangeBank Offer'

# %%
for i in cmbox:
    print(i.div.div.text)
# Out:
# Filters
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [35], line 2
#       1 for i in cmbox:
# ----> 2     print(i.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
cmbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=5g_mobile&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=ty
# ...

# %%
cmbox[1]
# Out:
# <div class="_1AtVbE col-12-12"><a class="_1nY1tt" href="/buying-guide/mobiles?sid=tyy,4io&amp;otracker=bg_from_browse_lhs" title="Buying Guide"><div><span>Need help?</span></div><div class="_1mVNvF"><span>Help me decide</span><svg class="ViewtL" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_2Zt1Py" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><img alt="Buying Guide" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/buying-guide-illustration_4dd325.png"/></a></div>

# %%
cmbox[2]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGDRGPZTSHNQ5H" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/poco-m4-5g-power-black-64-gb/p/itmdca739218a8a0?pid=MOBGDRGPZTSHNQ5H&amp;lid=LSTMOBGDRGPZTSHNQ5HK2U5VI&amp;marketplace=FLIPKART&amp;q=5g_mobile&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=9c1a47c9-cfdb-43fb-a941-24f9dea7bff8.MOBGDRGPZTSHNQ5H.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=w779evh1lc0000001682776795293&amp;qH=5ea6ea0c886e1490" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="POCO M4 5G (Power Black, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/l2jcccw0/mobile/i/1/y/-original-imagdu8gtefvchbn.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="che
# ...

# %%
cmbox[3]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGZBFUQMTHYHSH" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/vivo-t2x-5g-aurora-gold-128-gb/p/itmcf0e8d553142a?pid=MOBGZBFUQMTHYHSH&amp;lid=LSTMOBGZBFUQMTHYHSHXWZGSH&amp;marketplace=FLIPKART&amp;q=5g_mobile&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=9c1a47c9-cfdb-43fb-a941-24f9dea7bff8.MOBGZBFUQMTHYHSH.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=w779evh1lc0000001682776795293&amp;qH=5ea6ea0c886e1490" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="vivo T2x 5G (Aurora Gold, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/c/s/x/-original-imagzjhwaaewgj8r.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="ch
# ...

# %%
cmbox[4]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGZBFUZEMCKRGE" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/vivo-t2x-5g-glimmer-black-128-gb/p/itmcf0e8d553142a?pid=MOBGZBFUZEMCKRGE&amp;lid=LSTMOBGZBFUZEMCKRGEHY68W1&amp;marketplace=FLIPKART&amp;q=5g_mobile&amp;store=tyy%2F4io&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=9c1a47c9-cfdb-43fb-a941-24f9dea7bff8.MOBGZBFUZEMCKRGE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=w779evh1lc0000001682776795293&amp;qH=5ea6ea0c886e1490" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="vivo T2x 5G (Glimmer Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/4/h/e/-original-imagzjhwmsamexfk.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type
# ...

# %%
cmbox[2].div.div.find_all("div",{"class":""})
# Out:
# [<div><div class="CXW8mj" style="height:200px;width:200px"><img alt="POCO M4 5G (Power Black, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/l2jcccw0/mobile/i/1/y/-original-imagdu8gtefvchbn.jpeg?q=70"/></div></div>,
#  <div><div class="_2Tpdn3" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div></div>]

# %%
for i in cmbox:
    print(i.div.div.find_all("div",{"class":""})[0].text)
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [46], line 2
#       1 for i in cmbox:
# ----> 2     print(i.div.div.find_all("div",{"class":""})[0].text)
#       3     print("\n")
#
# IndexError: list index out of range

# %%
cmbox[3].div.div.div.a['href']
# Out:
# '/vivo-t2x-5g-aurora-gold-128-gb/p/itmcf0e8d553142a?pid=MOBGZBFUQMTHYHSH&lid=LSTMOBGZBFUQMTHYHSHXWZGSH&marketplace=FLIPKART&q=5g_mobile&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=9c1a47c9-cfdb-43fb-a941-24f9dea7bff8.MOBGZBFUQMTHYHSH.SEARCH&ppt=None&ppn=None&ssid=w779evh1lc0000001682776795293&qH=5ea6ea0c886e1490'

# %%
box_5=cmbox[3].div.div.div.div

# %%
len(box_5)
# Out:
# 3

# %%
box_5
# Out:
# <div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="vivo T2x 5G (Aurora Gold, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/c/s/x/-original-imagzjhwaaewgj8r.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></pa
# ...

# %%
box_6=box_5.div

# %%
len(box_6)
# Out:
# 1

# %%
box_6
# Out:
# <div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="vivo T2x 5G (Aurora Gold, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/c/s/x/-original-imagzjhwaaewgj8r.jpeg?q=70"/></div></div></div>

# %%
box_5
# Out:
# <div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="vivo T2x 5G (Aurora Gold, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/c/s/x/-original-imagzjhwaaewgj8r.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></pa
# ...

# %%
box_6=cmbox[2].div.div.div.a

# %%
len(box_6)
# Out:
# 2

# %%
box_6.div
# Out:
# <div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="POCO M4 5G (Power Black, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/l2jcccw0/mobile/i/1/y/-original-imagdu8gtefvchbn.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></p
# ...

# %%
box_6.div.div.div.div.img['src']
# Out:
# 'https://rukminim1.flixcart.com/image/312/312/l2jcccw0/mobile/i/1/y/-original-imagdu8gtefvchbn.jpeg?q=70'

# %%
len(box_6)
# Out:
# 2

# %%
box_6['href']
# Out:
# '/poco-m4-5g-power-black-64-gb/p/itmdca739218a8a0?pid=MOBGDRGPZTSHNQ5H&lid=LSTMOBGDRGPZTSHNQ5HK2U5VI&marketplace=FLIPKART&q=5g_mobile&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=9c1a47c9-cfdb-43fb-a941-24f9dea7bff8.MOBGDRGPZTSHNQ5H.SEARCH&ppt=None&ppn=None&ssid=w779evh1lc0000001682776795293&qH=5ea6ea0c886e1490'

# %%
box_5
# Out:
# <div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="vivo T2x 5G (Aurora Gold, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/c/s/x/-original-imagzjhwaaewgj8r.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></pa
# ...

# %%
box=cmbox[2].div.div.div

# %%
box_1=box.a

# %%
len(box_1)
# Out:
# 2

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [131], line 1
# ----> 1 box_1[:-1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\element.py:1519, in Tag.__getitem__(self, key)
#    1516 def __getitem__(self, key):
#    1517     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518     and throws an exception if it's not there."""
# -> 1519     return self.attrs[key]
#
# TypeError: unhashable type: 'slice'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
